# %% [markdown]
# # IRIS dataset classification using ANN

# %% [markdown]
# In 1936, the British statistician and biologist Ronald Fisher published The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis.
#
# Two of the three species were collected on the Gaspé Peninsula "all from the same pasture, collected on the same day and measured at the same time by the same person with the same instrument".
#
# The dataset consists of 50 samples from each of the three species of iris.
#
# Four traits were measured for each sample: length and width of calyx and petals in centimetres.
#
# Identification of the fescue species by the dimensions of the different petals
#
# - https://en.wikipedia.org/wiki/Iris_flower_data_set
# - https://www.kaggle.com/arshid/iris-flower-dataset

# %% [markdown]
# # Task
#
# Your goal is to create a classification neural network to distinguish different species of killer whales.
#
# We will use the same data as in the k-means/SVM chapter, you can build on it.
#
# As you work through this task, the following points will be completed in turn:
#
# - Retrieve the data and display the basic statistics
# - Use binary encoding to prepare the data.
# - Standardize the input values using StandardScaler
# - Split the data into training, test and validation
#
# - Create a neural network model, don't be afraid to experiment with the number of hidden layers and their size
# - You will probably need Dense layers, you can try the Drop layer
# - Use a relay as the activation function, use a Softmax layer for the output
#
# - When learning, use the categorical_crossentropy cost function
# - The optimization algorithm will be ADAM
# - You can collect other accuracy metrics
#
# - Save the learned model to a file
#
# - Test the learned model, find R2 and accuracy
# - Plot the substitution matrix
#
# - Plot the learning history
#
# - Test the model on your input data (create inference)

# %% [markdown]
# # Data retrieval and basic statistics
# - data preview
# - basic statistics
# - NULL values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../dataset/IRIS.csv")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # Data visualization
# - distribution of values

# %%
sns.pairplot(data, hue="species")
plt.show()

# %% [markdown]
# # Data preparation
# - binary encoding
# - standardization of input variables

# %%
X = data.iloc[:, 0:4].values
y = data.iloc[:, 4].values

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

# %% [markdown]
# ## Neural network modelling
#
# Neural network model
# * Sequential model - data flows from the input layer through hidden layers to the output layer.
# * Dense layer connects each neuron from the previous layer to each neuron in the layer.
# * Drop layer randomly sets the input units to 0 at each step during the training period, which helps prevent overfitting.
# * RELU and Softmax activation functions are used.
# * The last Softmax function is used in the output layer because this project is a classification project.
#
# * Compilation is the last step in model building.
# * The optimizer we use is Adam. Adam is an optimization algorithm that can be used instead of the classical stochastic gradient descent procedure to iteratively update the network weights based on the training data.
# * Cost function - categorical_crossentropy, a special loss function for classification (https://keras.io/api/losses/probabilistic_losses/#categoricalcrossentropy-class).
# * Another metric - Accuracy - is computed during learning.
#
#
# Model: "sequential"
#  Layer (type)                Output Shape              Param #
#  dense (Dense)               (None, 16)                80
#  dropout (Dropout)           (None, 16)                0
#  dense_1 (Dense)             (None, 16)                272
#  dropout_1 (Dropout)         (None, 16)                0
#  dense_2 (Dense)             (None, 3)                 51
#
# Total params: 403
# Trainable params: 403
# Non-trainable params: 0
#
# ![image.png](attachment:image.png)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input

model = Sequential()
model.add(Input(shape=(4,)))

model.add(Dense(16, activation="relu"))
model.add(Dropout(0.2))

model.add(Dense(16, activation="relu"))
model.add(Dropout(0.2))

model.add(Dense(3, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 403 (1.57 KB)
#  Trainable params: 403 (1.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=8,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3230 - loss: 1.1567 - val_accuracy: 0.2083 - val_loss: 1.1304
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3465 - loss: 1.0724 - val_accuracy: 0.2083 - val_loss: 1.0985
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4043 - loss: 1.0600 - val_accuracy: 0.5417 - val_loss: 1.0649
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5276 - loss: 1.0170 - val_accuracy: 0.5417 - val_loss: 1.0323
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6387 - loss: 0.9621 - val_accuracy: 0.5417 - val_loss: 1.0084
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5538 - loss: 0.9586 - val_accuracy: 0.5417 - val_loss: 0.9852
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6364 - loss: 0.9208 - val_accuracy: 0.5833 - val_loss: 0.9584
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7322 - loss: 0.8295 - val_accuracy: 0.5833 - val_loss: 0.9313
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6913 - loss: 0.8151 - val_accuracy: 0.5833 - val_loss: 0.8968
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6840 - loss: 0.7691 - val_accuracy: 0.6250 - val_loss: 0.8640
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7297 - loss: 0.7154 - val_accuracy: 0.6250 - val_loss: 0.8294
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8146 - loss: 0.6435 - val_accuracy: 0.6250 - val_loss: 0.7920
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9168 - loss: 0.1555 - val_accuracy: 0.9167 - val_loss: 0.2055
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8805 - loss: 0.2088 - val_accuracy: 0.9167 - val_loss: 0.2235
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9666 - loss: 0.1227 - val_accuracy: 0.9167 - val_loss: 0.2316
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9614 - loss: 0.1266 - val_accuracy: 0.9167 - val_loss: 0.2337
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9216 - loss: 0.1637 - val_accuracy: 0.9167 - val_loss: 0.2047
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9838 - loss: 0.1267 - val_accuracy: 0.9167 - val_loss: 0.2024
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9565 - loss: 0.1008 - val_accuracy: 0.9167 - val_loss: 0.1961
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9542 - loss: 0.1451 - val_accuracy: 0.9167 - val_loss: 0.1988
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9342 - loss: 0.1713 - val_accuracy: 0.9167 - val_loss: 0.2113
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9171 - loss: 0.1404 - val_accuracy: 0.9167 - val_loss: 0.2329
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9397 - loss: 0.2058 - val_accuracy: 0.9167 - val_loss: 0.2386
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9808 - loss: 0.0997 - val_accuracy: 0.9167 - val_loss: 0.2386
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.1440 - val_accuracy: 0.9167 - val_loss: 0.2136
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9886 - loss: 0.0684 - val_accuracy: 0.9167 - val_loss: 0.2104
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9679 - loss: 0.1190 - val_accuracy: 0.9167 - val_loss: 0.2038
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9637 - loss: 0.1204 - val_accuracy: 0.9167 - val_loss: 0.2052
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9715 - loss: 0.1052 - val_accuracy: 0.9167 - val_loss: 0.2130
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9781 - loss: 0.1155 - val_accuracy: 0.9167 - val_loss: 0.2002
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9710 - loss: 0.1212 - val_accuracy: 0.9167 - val_loss: 0.1915
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9838 - loss: 0.0869 - val_accuracy: 0.9167 - val_loss: 0.1904
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9422 - loss: 0.1199 - val_accuracy: 0.9167 - val_loss: 0.2007
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9778 - loss: 0.1202 - val_accuracy: 0.9167 - val_loss: 0.2071
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9893 - loss: 0.0683 - val_accuracy: 0.9167 - val_loss: 0.2147
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9739 - loss: 0.0998 - val_accuracy: 0.9167 - val_loss: 0.2127
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9822 - loss: 0.0793 - val_accuracy: 0.9167 - val_loss: 0.2013
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9770 - loss: 0.0804 - val_accuracy: 0.9167 - val_loss: 0.1941
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9352 - loss: 0.1219 - val_accuracy: 0.9167 - val_loss: 0.2052
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9550 - loss: 0.0992 - val_accuracy: 0.9167 - val_loss: 0.2118
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9612 - loss: 0.1458 - val_accuracy: 0.9167 - val_loss: 0.1989
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9745 - loss: 0.1223 - val_accuracy: 0.9167 - val_loss: 0.1872
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.1263 - val_accuracy: 0.9167 - val_loss: 0.1857
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9929 - loss: 0.0744 - val_accuracy: 0.9167 - val_loss: 0.1941
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9503 - loss: 0.1277 - val_accuracy: 0.9167 - val_loss: 0.1937
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9074 - loss: 0.1607 - val_accuracy: 0.9167 - val_loss: 0.1958
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9844 - loss: 0.0717 - val_accuracy: 0.9167 - val_loss: 0.1872
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9321 - loss: 0.1351 - val_accuracy: 0.9167 - val_loss: 0.1835
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9079 - loss: 0.1970 - val_accuracy: 0.9167 - val_loss: 0.2050
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9529 - loss: 0.1073 - val_accuracy: 0.9167 - val_loss: 0.2091
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9499 - loss: 0.1792 - val_accuracy: 0.9167 - val_loss: 0.1988
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9884 - loss: 0.0661 - val_accuracy: 0.9167 - val_loss: 0.1924

# %% [markdown]
# # Save the model

# %%
model.save("iris_model.keras")

# %% [markdown]
# # Show learning history

# %%
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # Model Verification
# - Prediction of test values
# - Accuracy
# - Confusion matrix of training and test data

# %%
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
accuracy = accuracy_score(
    np.argmax(y_test, axis=1),
    np.argmax(y_pred, axis=1)
)

accuracy
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1.0

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(
    np.argmax(y_test, axis=1),
    np.argmax(y_pred, axis=1)
)

sns.heatmap(cm, annot=True, cmap="Blues")
plt.show()

# %% [markdown]
# # Using the model
# The answer should therefore be Iris virginica

# %%
import numpy as np

sample = scaler.transform(np.array([[1, 2, 1, 2]]))
test_predictions = model.predict(sample)

print(f"Iris setosa:     {test_predictions[0][0]}")
print(f"Iris versicolor: {test_predictions[0][1]}")
print(f"Iris virginica:  {test_predictions[0][2]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Iris setosa:     0.8908340930938721
# Iris versicolor: 0.022875286638736725
# Iris virginica:  0.0862906351685524
